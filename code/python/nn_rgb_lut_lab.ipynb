# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import logging
from sklearn.preprocessing import StandardScaler
import spectral
import random
from skimage import color
import matplotlib.pyplot as plt
import os
import copy

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set a fixed seed for reproducibility
seed = 10
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

###########################################
# Helper functions
###########################################
def process_xyz(cube, bands, ill, CMFs):
    """
    Converts hyperspectral cube data to XYZ using the illuminant and CMFs.
    """
    ill_interp = np.interp(bands, ill[:, 0], ill[:, 1])
    CMFs_interp = np.column_stack([
        np.interp(bands, CMFs[:, 0], CMFs[:, 1]),
        np.interp(bands, CMFs[:, 0], CMFs[:, 2]),
        np.interp(bands, CMFs[:, 0], CMFs[:, 3])
    ])
    sp_tristREF = CMFs_interp * ill_interp[:, None]
    xyz = np.dot(cube, sp_tristREF) / np.sum(sp_tristREF[:, 1], axis=0)
    return xyz

def apply_tone_curve_lab_L(lab_input, lab_ref, white_coords=(0,0), black_coords=(1,0)):
    """
    Applies tone curve correction in Lab space only on the L channel,
    using white and black patch anchors, leaving a and b unchanged.
    
    Parameters:
      lab_input: numpy array of shape (H, W, 3) with input Lab values.
      lab_ref: numpy array of shape (H, W, 3) with reference Lab values.
      white_coords: tuple (row, col) for white patch location.
      black_coords: tuple (row, col) for black patch location.
      
    Returns:
      lab_corrected: numpy array of shape (H, W, 3) after tone curve correction.
    """
    # Extract L values for white and black patches
    L_in_white = lab_input[white_coords[0], white_coords[1], 0]
    L_in_black = lab_input[black_coords[0], black_coords[1], 0]
    L_ref_white = lab_ref[white_coords[0], white_coords[1], 0]
    L_ref_black = lab_ref[black_coords[0], black_coords[1], 0]
    
    # Build tone curve for L channel
    # Map input L values [L_in_black, L_in_white] to reference L values [L_ref_black, L_ref_white]
    lab_corrected = lab_input.copy()
    L_channel = lab_input[..., 0].flatten()
    L_corrected = np.interp(L_channel, [L_in_black, L_in_white], [L_ref_black, L_ref_white])
    lab_corrected[..., 0] = L_corrected.reshape(lab_input.shape[:2])
    # a and b channels remain unchanged.
    return lab_corrected

###########################################
# 1. Load spectral data
###########################################
logging.info('Loading spectral data...')
ill = np.loadtxt('../../data/CIE_D65.txt')          
CMFs = np.loadtxt('../../data/CIE2degCMFs_1931.txt')

cube_path = '../../data/colorChecker_SG/cubes/cubeCC_no6-ekta100-expo3.hdr'
cube = spectral.open_image(cube_path)
cube_ref = spectral.open_image('../../data/colorChecker_SG/cubeCC_DigitalSG_REF.hdr')

cube_data = cube.load()         
cube_ref_data = cube_ref.load()

wl_input = np.array(cube.metadata['wavelength'], dtype=float)
wl_ref   = np.array(cube_ref.metadata['wavelength'], dtype=float)

###########################################
# 2. Process XYZ and Convert to Lab
###########################################
logging.info('Processing XYZ data...')
xyz_input = process_xyz(cube_data, wl_input, ill, CMFs)
xyz_ref   = process_xyz(cube_ref_data, wl_ref, ill, CMFs)
rgb_ref = color.xyz2rgb(xyz_ref)

# Reshape to 10x14 (chart is 10x14 patches)
xyz_input_2d = xyz_input.reshape(10, 14, 3)
xyz_ref_2d   = xyz_ref.reshape(10, 14, 3)

# Convert XYZ to Lab (using skimage.color.xyz2lab)
lab_input = color.xyz2lab(xyz_input)
lab_ref   = color.xyz2lab(xyz_ref)

# Reshape into 10x14 grids
lab_input_2d = lab_input.reshape(10, 14, 3)
lab_ref_2d   = lab_ref.reshape(10, 14, 3)


###########################################
# 3. Apply Tone Curve Correction in Lab (L channel only)
###########################################
logging.info('Applying tone curve correction on L channel in Lab domain...')
# Assume white patch at (0,0) and black patch at (1,0)
lab_input_corrected = apply_tone_curve_lab_L(lab_input_2d, lab_ref_2d, white_coords=(0,0), black_coords=(1,0))
rgb_input = color.lab2rgb(lab_input_corrected)
    
###########################################
# Visualize Tone-Corrected Image (Before NN)
###########################################
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(color.lab2rgb(lab_input_2d))
plt.title('Original Input (Lab -> RGB)')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(rgb_input)
plt.title('Tone-Corrected Input (Lab, L-only)')
plt.axis('off')
plt.show()

###########################################
# 4. Normalize Data in Lab Space (for NN)
###########################################
logging.info('Normalizing RGB data...')
rgb_input_2d = rgb_input.reshape(-1, rgb_input.shape[-1])
rgb_ref_2d   = rgb_ref.reshape(-1, rgb_ref.shape[-1])

# scaler_input = MinMaxScaler()
# scaler_ref = MinMaxScaler()
# X_norm = scaler_input.fit_transform(rgb_input_2d)
# Y_norm = scaler_ref.fit_transform(rgb_ref_2d)


scaler_input = StandardScaler()
scaler_ref = StandardScaler()
X_norm = scaler_input.fit_transform(rgb_input_2d)
Y_norm = scaler_ref.fit_transform(rgb_ref_2d)

X_full = X_norm.reshape(rgb_input.shape)
Y_full = Y_norm.reshape(rgb_ref.shape)

###########################################
# 4. Prepare training data
###########################################
X_flat = X_full.reshape(-1, 3)
Y_flat = Y_full.reshape(-1, 3)

n_pixels = X_flat.shape[0]
train_size = int(0.8 * n_pixels)
train_indices = np.random.choice(n_pixels, train_size, replace=False)
test_indices = np.setdiff1d(np.arange(n_pixels), train_indices)

X_train_split = X_flat[train_indices]
X_test_split  = X_flat[test_indices]
Y_train_split = Y_flat[train_indices]
Y_test_split  = Y_flat[test_indices]

X_train_torch = torch.tensor(X_train_split, dtype=torch.float32)
Y_train_torch = torch.tensor(Y_train_split, dtype=torch.float32)
X_test_torch  = torch.tensor(X_test_split, dtype=torch.float32)
Y_test_torch  = torch.tensor(Y_test_split, dtype=torch.float32)

###########################################
# 5. Define a simple MLP model
###########################################
class SimpleMLP(nn.Module):
    def __init__(self, input_size=3, hidden_size=128, output_size=3):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))
    
    
    

class HybridRGBLoss(nn.Module):
    def __init__(self, alpha=0.5, eps=1e-6):
        super(HybridRGBLoss, self).__init__()
        self.alpha = alpha  
        self.eps = eps  
        self.mse_loss = nn.MSELoss()

    def forward(self, y_pred, y_true):
        y_pred_norm = torch.nn.functional.normalize(y_pred, p=2, dim=1, eps=self.eps)
        y_true_norm = torch.nn.functional.normalize(y_true, p=2, dim=1, eps=self.eps)
        cosine_similarity = torch.sum(y_pred_norm * y_true_norm, dim=1)
        cosine_similarity = torch.clamp(cosine_similarity, -1.0, 1.0)
        angular_loss = 1 - cosine_similarity  
        mse_loss = self.mse_loss(y_pred, y_true)
        total_loss = self.alpha * angular_loss.mean() + (1 - self.alpha) * mse_loss
        return total_loss

class EarlyStopping:
    def __init__(self, patience=10, delta=0, verbose=False, path='best_model.pth'):
        self.patience = patience  # Number of epochs to wait for improvement
        self.delta = delta  # Minimum change to qualify as an improvement
        self.verbose = verbose  # Whether to print the stop message
        self.path = path  # Path to save the best model
        self.best_loss = None  # Best validation loss
        self.counter = 0  # Counter for how many epochs without improvement
        self.early_stop = False  # Flag to stop the training
        self.best_model_wts = None  # To store the best model's weights

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.best_model_wts = copy.deepcopy(model.state_dict())
        elif val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.best_model_wts = copy.deepcopy(model.state_dict())
            self.counter = 0  # Reset the counter
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print(f"Early stopping triggered after {self.counter} epochs with no improvement.")
                    
        return self.early_stop


model = SimpleMLP(input_size=3, hidden_size=128, output_size=3)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
# loss_function = HybridRGBLoss()
loss_function = nn.MSELoss()
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.5)  # Reduce LR every 200 epochs
early_stopping = EarlyStopping(patience= 50, delta = 0, verbose=True)


###########################################
# 6. Training loop (using MSE loss in RGB space)
###########################################
epochs = 2000
batch_size = 4
val_loss_min = float('inf')
train_losses = []
val_losses = []

logging.info('Training the model...')
for epoch in range(epochs):
    model.train()
    perm = torch.randperm(X_train_torch.size(0))
    X_train_shuffled = X_train_torch[perm]
    Y_train_shuffled = Y_train_torch[perm]
    epoch_train_loss = 0.0
    
    for i in range(0, X_train_shuffled.size(0), batch_size):
        X_batch = X_train_shuffled[i:i+batch_size]
        Y_batch = Y_train_shuffled[i:i+batch_size]
        
        optimizer.zero_grad()
        Y_pred = model(X_batch)
        loss = loss_function(Y_pred, Y_batch)
        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()
    
    scheduler.step()  # Reduce learning rate

    # Calculate average training loss for the epoch
    avg_train_loss = epoch_train_loss / (X_train_shuffled.size(0) // batch_size)
    train_losses.append(avg_train_loss)
    
    scheduler.step()  # Reduce learning rate

    # Calculate validation loss (on the test set)
    model.eval()
    with torch.no_grad():
        Y_val_pred = model(X_test_torch)
        val_loss = loss_function(Y_val_pred, Y_test_torch).item()
    val_losses.append(val_loss)

    # Print training and validation loss
    logging.info(f'Epoch {epoch+1}/{epochs} - Training Loss: {avg_train_loss:.4f} - Validation Loss: {val_loss:.4f}')
    
    # Check for early stopping
    early_stopping(val_loss, model)
    
    if early_stopping.early_stop:
        logging.info("Early stopping triggered.")
        break

# Load the best model weights
model.load_state_dict(early_stopping.best_model_wts)

###########################################
# 7. Apply correction and evaluate with ΔE2000
###########################################
logging.info('Applying correction to the full target...')
X_full_flat = X_full.reshape(-1, 3)
corrected_flat = model(torch.tensor(X_full_flat, dtype=torch.float32)).detach().numpy()
corrected_rgb = scaler_ref.inverse_transform(corrected_flat)
corrected_rgb_image = corrected_rgb.reshape(rgb_ref.shape)

# Convert corrected and reference RGB to Lab
corrected_lab = color.rgb2lab(corrected_rgb_image)
lab_ref = color.rgb2lab(rgb_ref)

# Compute ΔE2000 error map
error_map = color.deltaE_ciede2000(lab_ref, corrected_lab)

# Compute mean ΔE2000 error
# Flatten the error map for indexing
error_map_flat = error_map.reshape(-1)
# Extract only test-set errors using precomputed test_indices
test_error_values = error_map_flat[test_indices]
# Compute mean & max ΔE2000 error for the test set
mean_error_test = np.mean(test_error_values)
max_error_test = np.max(test_error_values)
print("Mean ΔE2000 Error:", mean_error_test)
print("Max ΔE2000 Error:", max_error_test)

# Get train set pixel positions in the image
test_positions = np.unravel_index(test_indices, lab_ref.shape[:2])

# Plot the ΔE2000 error map
plt.figure(figsize=(8, 6))
plt.imshow(error_map, cmap='jet', vmin=0, vmax=10)
plt.colorbar(label='ΔE2000')
plt.scatter(test_positions[1], test_positions[0], s=2, c='white', label='Test Patches', alpha=0.7)
plt.title('ΔE2000 Error Map')

# Add text annotations for Mean and Max Error and File name
file_name = os.path.splitext(os.path.basename(cube_path))[0]
file_name = file_name.split('_', 1)[-1]

plt.text(0.5, 1.1, f'Cube: {file_name}\nMean Error: {mean_error_test:.2f}\nMax Error: {max_error_test:.2f}', 
         ha='center', va='bottom', transform=plt.gca().transAxes, fontsize=12, color='black')

# Adjust layout to ensure the annotations are visible
plt.tight_layout(pad=3.0)
plt.show()

###########################################
# 8. Apply NN correction and evaluate with ΔE2000
###########################################
# logging.info('Applying correction to full data using the trained model...')
# X_full_flat = X_full.reshape(-1, 3)
# corrected_flat = model(torch.tensor(X_full_flat, dtype=torch.float32)).detach().numpy()
# corrected_lab = scaler_ref.inverse_transform(corrected_flat)
# corrected_lab_image = corrected_lab.reshape(lab_ref.reshape(10,14,3).shape)

# rgb_corrected = color.lab2rgb(corrected_lab_image)

# # Compute ΔE2000 error map using skimage.color.deltaE_ciede2000
# error_map = color.deltaE_ciede2000(color.rgb2lab(color.xyz2rgb(xyz_ref.reshape(10,14,3))), 
#                                    color.rgb2lab(rgb_corrected))
# mean_error = np.mean(error_map)
# max_error = np.max(error_map)
# print("Mean ΔE2000 Error:", mean_error)
# print("Max ΔE2000 Error:", max_error)

###########################################
# 9. Visualize the Results
###########################################
plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.imshow(color.lab2rgb(lab_input_2d))
plt.title('Original Input')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(color.lab2rgb(lab_ref_2d))
plt.title('Reference')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(corrected_rgb_image)
plt.title('NN Corrected')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 2025-03-19 23:36:09,288 - INFO - Loading spectral data...
# 2025-03-19 23:36:09,289 - INFO - Processing XYZ data...
# 2025-03-19 23:36:09,290 - INFO - Applying tone curve correction on L channel in Lab domain...
# 2025-03-19 23:36:09,326 - INFO - Normalizing RGB data...
# 2025-03-19 23:36:09,330 - INFO - Training the model...
# 2025-03-19 23:36:09,337 - INFO - Epoch 1/2000 - Training Loss: 0.7844 - Validation Loss: 0.5327
# 2025-03-19 23:36:09,345 - INFO - Epoch 2/2000 - Training Loss: 0.3781 - Validation Loss: 0.3508
# 2025-03-19 23:36:09,352 - INFO - Epoch 3/2000 - Training Loss: 0.3193 - Validation Loss: 0.3161
# 2025-03-19 23:36:09,359 - INFO - Epoch 4/2000 - Training Loss: 0.2885 - Validation Loss: 0.2818
# 2025-03-19 23:36:09,366 - INFO - Epoch 5/2000 - Training Loss: 0.2578 - Validation Loss: 0.2609
# 2025-03-19 23:36:09,374 - INFO - Epoch 6/2000 - Training Loss: 0.2301 - Validation Loss: 0.2381
# 2025-03-19 23:36:09,381 - INFO - Epoch 7/2000 - Training Loss: 0.2086 - Validation Loss: 0.2195
# 2025-03-19 23:36:09,388 - INFO - Epoch 8/2000 - Training Loss: 0.1882 - Validation Loss: 0.1961
# 2025-03-19 23:36:09,396 - INFO - Epoch 9/2000 - Training Loss: 0.1715 - Validation Loss: 0.1843
# 2025-03-19 23:36:09,403 - INFO - Epoch 10/2000 - Training Loss: 0.1573 - Validation Loss: 0.1774
# 2025-03-19 23:36:09,411 - INFO - Epoch 11/2000 - Training Loss: 0.1468 - Validation Loss: 0.1653
# 2025-03-19 23:36:09,418 - INFO - Epoch 12/2000 - Training Loss: 0.1372 - Validation Loss: 0.1543
# 2025-03-19 23:36:09,425 - INFO - Epoch 13/2000 - Training Loss: 0.1303 - Validation Loss: 0.1473
# 2025-03-19 23:36:09,432 - INFO - Epoch 14/2000 - Training Loss: 0.1236 - Validation Loss: 0.1350
# 2025-03-19 23:36:09,440 - INFO - Epoch 15/2000 - Training Loss: 0.1164 - Validation Loss: 0.1314
# 2025-03-19 23:36:09,447 - INFO - Epoch 16/2000 - Training Loss: 0.1104 - Validation Loss: 0.1254
# 2025-03-19 23:36:09,455 - INFO - Epoch 17/2000 - Training Loss: 0.1044 - Validation Loss: 0.1187
# 2025-03-19 23:36:09,462 - INFO - Epoch 18/2000 - Training Loss: 0.1008 - Validation Loss: 0.1086
# 2025-03-19 23:36:09,470 - INFO - Epoch 19/2000 - Training Loss: 0.0952 - Validation Loss: 0.1128
# 2025-03-19 23:36:09,477 - INFO - Epoch 20/2000 - Training Loss: 0.0924 - Validation Loss: 0.1051
# 2025-03-19 23:36:09,485 - INFO - Epoch 21/2000 - Training Loss: 0.0889 - Validation Loss: 0.1040
# 2025-03-19 23:36:09,492 - INFO - Epoch 22/2000 - Training Loss: 0.0857 - Validation Loss: 0.0991
# 2025-03-19 23:36:09,500 - INFO - Epoch 23/2000 - Training Loss: 0.0832 - Validation Loss: 0.0974
# 2025-03-19 23:36:09,508 - INFO - Epoch 24/2000 - Training Loss: 0.0808 - Validation Loss: 0.0919
# 2025-03-19 23:36:09,516 - INFO - Epoch 25/2000 - Training Loss: 0.0796 - Validation Loss: 0.0908
# 2025-03-19 23:36:09,523 - INFO - Epoch 26/2000 - Training Loss: 0.0755 - Validation Loss: 0.0903
# 2025-03-19 23:36:09,531 - INFO - Epoch 27/2000 - Training Loss: 0.0744 - Validation Loss: 0.0849
# 2025-03-19 23:36:09,539 - INFO - Epoch 28/2000 - Training Loss: 0.0724 - Validation Loss: 0.0898
# 2025-03-19 23:36:09,546 - INFO - Epoch 29/2000 - Training Loss: 0.0702 - Validation Loss: 0.0865
# 2025-03-19 23:36:09,554 - INFO - Epoch 30/2000 - Training Loss: 0.0688 - Validation Loss: 0.0826
# 2025-03-19 23:36:09,562 - INFO - Epoch 31/2000 - Training Loss: 0.0682 - Validation Loss: 0.0868
# 2025-03-19 23:36:09,569 - INFO - Epoch 32/2000 - Training Loss: 0.0665 - Validation Loss: 0.0825
# 2025-03-19 23:36:09,577 - INFO - Epoch 33/2000 - Training Loss: 0.0657 - Validation Loss: 0.0839
# 2025-03-19 23:36:09,585 - INFO - Epoch 34/2000 - Training Loss: 0.0638 - Validation Loss: 0.0848
# 2025-03-19 23:36:09,592 - INFO - Epoch 35/2000 - Training Loss: 0.0626 - Validation Loss: 0.0793
# 2025-03-19 23:36:09,600 - INFO - Epoch 36/2000 - Training Loss: 0.0605 - Validation Loss: 0.0787
# 2025-03-19 23:36:09,607 - INFO - Epoch 37/2000 - Training Loss: 0.0593 - Validation Loss: 0.0785
# 2025-03-19 23:36:09,614 - INFO - Epoch 38/2000 - Training Loss: 0.0588 - Validation Loss: 0.0779
# 2025-03-19 23:36:09,621 - INFO - Epoch 39/2000 - Training Loss: 0.0579 - Validation Loss: 0.0739
# 2025-03-19 23:36:09,629 - INFO - Epoch 40/2000 - Training Loss: 0.0558 - Validation Loss: 0.0791
# 2025-03-19 23:36:09,636 - INFO - Epoch 41/2000 - Training Loss: 0.0556 - Validation Loss: 0.0744
# 2025-03-19 23:36:09,643 - INFO - Epoch 42/2000 - Training Loss: 0.0543 - Validation Loss: 0.0731
# 2025-03-19 23:36:09,650 - INFO - Epoch 43/2000 - Training Loss: 0.0556 - Validation Loss: 0.0716
# 2025-03-19 23:36:09,658 - INFO - Epoch 44/2000 - Training Loss: 0.0538 - Validation Loss: 0.0776
# 2025-03-19 23:36:09,665 - INFO - Epoch 45/2000 - Training Loss: 0.0530 - Validation Loss: 0.0766
# 2025-03-19 23:36:09,672 - INFO - Epoch 46/2000 - Training Loss: 0.0540 - Validation Loss: 0.0787
# 2025-03-19 23:36:09,679 - INFO - Epoch 47/2000 - Training Loss: 0.0529 - Validation Loss: 0.0697
# 2025-03-19 23:36:09,688 - INFO - Epoch 48/2000 - Training Loss: 0.0503 - Validation Loss: 0.0712
# 2025-03-19 23:36:09,695 - INFO - Epoch 49/2000 - Training Loss: 0.0494 - Validation Loss: 0.0691
# 2025-03-19 23:36:09,703 - INFO - Epoch 50/2000 - Training Loss: 0.0482 - Validation Loss: 0.0710
# 2025-03-19 23:36:09,710 - INFO - Epoch 51/2000 - Training Loss: 0.0490 - Validation Loss: 0.0702
# 2025-03-19 23:36:09,717 - INFO - Epoch 52/2000 - Training Loss: 0.0470 - Validation Loss: 0.0701
# 2025-03-19 23:36:09,724 - INFO - Epoch 53/2000 - Training Loss: 0.0467 - Validation Loss: 0.0720
# 2025-03-19 23:36:09,732 - INFO - Epoch 54/2000 - Training Loss: 0.0473 - Validation Loss: 0.0677
# 2025-03-19 23:36:09,739 - INFO - Epoch 55/2000 - Training Loss: 0.0453 - Validation Loss: 0.0698
# 2025-03-19 23:36:09,746 - INFO - Epoch 56/2000 - Training Loss: 0.0447 - Validation Loss: 0.0696
# 2025-03-19 23:36:09,754 - INFO - Epoch 57/2000 - Training Loss: 0.0453 - Validation Loss: 0.0662
# 2025-03-19 23:36:09,762 - INFO - Epoch 58/2000 - Training Loss: 0.0446 - Validation Loss: 0.0690
# 2025-03-19 23:36:09,769 - INFO - Epoch 59/2000 - Training Loss: 0.0447 - Validation Loss: 0.0699
# 2025-03-19 23:36:09,776 - INFO - Epoch 60/2000 - Training Loss: 0.0453 - Validation Loss: 0.0669
# 2025-03-19 23:36:09,784 - INFO - Epoch 61/2000 - Training Loss: 0.0444 - Validation Loss: 0.0653
# 2025-03-19 23:36:09,791 - INFO - Epoch 62/2000 - Training Loss: 0.0437 - Validation Loss: 0.0633
# 2025-03-19 23:36:09,798 - INFO - Epoch 63/2000 - Training Loss: 0.0435 - Validation Loss: 0.0671
# 2025-03-19 23:36:09,806 - INFO - Epoch 64/2000 - Training Loss: 0.0425 - Validation Loss: 0.0662
# 2025-03-19 23:36:09,813 - INFO - Epoch 65/2000 - Training Loss: 0.0423 - Validation Loss: 0.0638
# 2025-03-19 23:36:09,820 - INFO - Epoch 66/2000 - Training Loss: 0.0423 - Validation Loss: 0.0653
# 2025-03-19 23:36:09,828 - INFO - Epoch 67/2000 - Training Loss: 0.0414 - Validation Loss: 0.0656
# 2025-03-19 23:36:09,835 - INFO - Epoch 68/2000 - Training Loss: 0.0408 - Validation Loss: 0.0646
# 2025-03-19 23:36:09,842 - INFO - Epoch 69/2000 - Training Loss: 0.0432 - Validation Loss: 0.0667
# 2025-03-19 23:36:09,849 - INFO - Epoch 70/2000 - Training Loss: 0.0407 - Validation Loss: 0.0682
# 2025-03-19 23:36:09,857 - INFO - Epoch 71/2000 - Training Loss: 0.0405 - Validation Loss: 0.0686
# 2025-03-19 23:36:09,864 - INFO - Epoch 72/2000 - Training Loss: 0.0411 - Validation Loss: 0.0680
# 2025-03-19 23:36:09,872 - INFO - Epoch 73/2000 - Training Loss: 0.0393 - Validation Loss: 0.0637
# 2025-03-19 23:36:09,879 - INFO - Epoch 74/2000 - Training Loss: 0.0404 - Validation Loss: 0.0711
# 2025-03-19 23:36:09,887 - INFO - Epoch 75/2000 - Training Loss: 0.0406 - Validation Loss: 0.0612
# 2025-03-19 23:36:09,894 - INFO - Epoch 76/2000 - Training Loss: 0.0395 - Validation Loss: 0.0647
# 2025-03-19 23:36:09,901 - INFO - Epoch 77/2000 - Training Loss: 0.0397 - Validation Loss: 0.0649
# 2025-03-19 23:36:09,909 - INFO - Epoch 78/2000 - Training Loss: 0.0380 - Validation Loss: 0.0649
# 2025-03-19 23:36:09,916 - INFO - Epoch 79/2000 - Training Loss: 0.0390 - Validation Loss: 0.0691
# 2025-03-19 23:36:09,923 - INFO - Epoch 80/2000 - Training Loss: 0.0385 - Validation Loss: 0.0660
# 2025-03-19 23:36:09,931 - INFO - Epoch 81/2000 - Training Loss: 0.0390 - Validation Loss: 0.0632
# 2025-03-19 23:36:09,938 - INFO - Epoch 82/2000 - Training Loss: 0.0381 - Validation Loss: 0.0663
# 2025-03-19 23:36:09,945 - INFO - Epoch 83/2000 - Training Loss: 0.0367 - Validation Loss: 0.0616
# 2025-03-19 23:36:09,953 - INFO - Epoch 84/2000 - Training Loss: 0.0410 - Validation Loss: 0.0646
# 2025-03-19 23:36:09,960 - INFO - Epoch 85/2000 - Training Loss: 0.0379 - Validation Loss: 0.0639
# 2025-03-19 23:36:09,967 - INFO - Epoch 86/2000 - Training Loss: 0.0356 - Validation Loss: 0.0649
# 2025-03-19 23:36:09,975 - INFO - Epoch 87/2000 - Training Loss: 0.0380 - Validation Loss: 0.0613
# 2025-03-19 23:36:09,982 - INFO - Epoch 88/2000 - Training Loss: 0.0405 - Validation Loss: 0.0634
# 2025-03-19 23:36:09,989 - INFO - Epoch 89/2000 - Training Loss: 0.0379 - Validation Loss: 0.0657
# 2025-03-19 23:36:09,997 - INFO - Epoch 90/2000 - Training Loss: 0.0370 - Validation Loss: 0.0623
# 2025-03-19 23:36:10,004 - INFO - Epoch 91/2000 - Training Loss: 0.0392 - Validation Loss: 0.0641
# 2025-03-19 23:36:10,011 - INFO - Epoch 92/2000 - Training Loss: 0.0384 - Validation Loss: 0.0653
# 2025-03-19 23:36:10,019 - INFO - Epoch 93/2000 - Training Loss: 0.0357 - Validation Loss: 0.0598
# 2025-03-19 23:36:10,026 - INFO - Epoch 94/2000 - Training Loss: 0.0349 - Validation Loss: 0.0624
# 2025-03-19 23:36:10,033 - INFO - Epoch 95/2000 - Training Loss: 0.0356 - Validation Loss: 0.0645
# 2025-03-19 23:36:10,041 - INFO - Epoch 96/2000 - Training Loss: 0.0350 - Validation Loss: 0.0595
# 2025-03-19 23:36:10,048 - INFO - Epoch 97/2000 - Training Loss: 0.0350 - Validation Loss: 0.0622
# 2025-03-19 23:36:10,056 - INFO - Epoch 98/2000 - Training Loss: 0.0355 - Validation Loss: 0.0611
# 2025-03-19 23:36:10,063 - INFO - Epoch 99/2000 - Training Loss: 0.0340 - Validation Loss: 0.0586
# 2025-03-19 23:36:10,070 - INFO - Epoch 100/2000 - Training Loss: 0.0357 - Validation Loss: 0.0659
# 2025-03-19 23:36:10,078 - INFO - Epoch 101/2000 - Training Loss: 0.0334 - Validation Loss: 0.0580
# 2025-03-19 23:36:10,086 - INFO - Epoch 102/2000 - Training Loss: 0.0355 - Validation Loss: 0.0653
# 2025-03-19 23:36:10,093 - INFO - Epoch 103/2000 - Training Loss: 0.0348 - Validation Loss: 0.0647
# 2025-03-19 23:36:10,101 - INFO - Epoch 104/2000 - Training Loss: 0.0348 - Validation Loss: 0.0596
# 2025-03-19 23:36:10,108 - INFO - Epoch 105/2000 - Training Loss: 0.0336 - Validation Loss: 0.0581
# 2025-03-19 23:36:10,116 - INFO - Epoch 106/2000 - Training Loss: 0.0332 - Validation Loss: 0.0584
# 2025-03-19 23:36:10,124 - INFO - Epoch 107/2000 - Training Loss: 0.0342 - Validation Loss: 0.0583
# 2025-03-19 23:36:10,131 - INFO - Epoch 108/2000 - Training Loss: 0.0336 - Validation Loss: 0.0607
# 2025-03-19 23:36:10,138 - INFO - Epoch 109/2000 - Training Loss: 0.0337 - Validation Loss: 0.0561
# 2025-03-19 23:36:10,146 - INFO - Epoch 110/2000 - Training Loss: 0.0330 - Validation Loss: 0.0573
# 2025-03-19 23:36:10,153 - INFO - Epoch 111/2000 - Training Loss: 0.0353 - Validation Loss: 0.0575
# 2025-03-19 23:36:10,160 - INFO - Epoch 112/2000 - Training Loss: 0.0328 - Validation Loss: 0.0617
# 2025-03-19 23:36:10,167 - INFO - Epoch 113/2000 - Training Loss: 0.0332 - Validation Loss: 0.0577
# 2025-03-19 23:36:10,175 - INFO - Epoch 114/2000 - Training Loss: 0.0340 - Validation Loss: 0.0567
# 2025-03-19 23:36:10,182 - INFO - Epoch 115/2000 - Training Loss: 0.0334 - Validation Loss: 0.0683
# 2025-03-19 23:36:10,189 - INFO - Epoch 116/2000 - Training Loss: 0.0342 - Validation Loss: 0.0570
# 2025-03-19 23:36:10,197 - INFO - Epoch 117/2000 - Training Loss: 0.0317 - Validation Loss: 0.0572
# 2025-03-19 23:36:10,204 - INFO - Epoch 118/2000 - Training Loss: 0.0327 - Validation Loss: 0.0634
# 2025-03-19 23:36:10,211 - INFO - Epoch 119/2000 - Training Loss: 0.0332 - Validation Loss: 0.0625
# 2025-03-19 23:36:10,218 - INFO - Epoch 120/2000 - Training Loss: 0.0307 - Validation Loss: 0.0568
# 2025-03-19 23:36:10,226 - INFO - Epoch 121/2000 - Training Loss: 0.0314 - Validation Loss: 0.0575
# 2025-03-19 23:36:10,233 - INFO - Epoch 122/2000 - Training Loss: 0.0354 - Validation Loss: 0.0586
# 2025-03-19 23:36:10,241 - INFO - Epoch 123/2000 - Training Loss: 0.0330 - Validation Loss: 0.0617
# 2025-03-19 23:36:10,248 - INFO - Epoch 124/2000 - Training Loss: 0.0322 - Validation Loss: 0.0615
# 2025-03-19 23:36:10,255 - INFO - Epoch 125/2000 - Training Loss: 0.0308 - Validation Loss: 0.0593
# 2025-03-19 23:36:10,262 - INFO - Epoch 126/2000 - Training Loss: 0.0327 - Validation Loss: 0.0598
# 2025-03-19 23:36:10,269 - INFO - Epoch 127/2000 - Training Loss: 0.0306 - Validation Loss: 0.0540
# 2025-03-19 23:36:10,277 - INFO - Epoch 128/2000 - Training Loss: 0.0316 - Validation Loss: 0.0617
# 2025-03-19 23:36:10,284 - INFO - Epoch 129/2000 - Training Loss: 0.0325 - Validation Loss: 0.0622
# 2025-03-19 23:36:10,291 - INFO - Epoch 130/2000 - Training Loss: 0.0317 - Validation Loss: 0.0581
# 2025-03-19 23:36:10,300 - INFO - Epoch 131/2000 - Training Loss: 0.0315 - Validation Loss: 0.0593
# 2025-03-19 23:36:10,307 - INFO - Epoch 132/2000 - Training Loss: 0.0312 - Validation Loss: 0.0595
# 2025-03-19 23:36:10,314 - INFO - Epoch 133/2000 - Training Loss: 0.0314 - Validation Loss: 0.0569
# 2025-03-19 23:36:10,322 - INFO - Epoch 134/2000 - Training Loss: 0.0307 - Validation Loss: 0.0564
# 2025-03-19 23:36:10,329 - INFO - Epoch 135/2000 - Training Loss: 0.0309 - Validation Loss: 0.0576
# 2025-03-19 23:36:10,336 - INFO - Epoch 136/2000 - Training Loss: 0.0296 - Validation Loss: 0.0551
# 2025-03-19 23:36:10,343 - INFO - Epoch 137/2000 - Training Loss: 0.0304 - Validation Loss: 0.0555
# 2025-03-19 23:36:10,350 - INFO - Epoch 138/2000 - Training Loss: 0.0315 - Validation Loss: 0.0596
# 2025-03-19 23:36:10,358 - INFO - Epoch 139/2000 - Training Loss: 0.0301 - Validation Loss: 0.0580
# 2025-03-19 23:36:10,365 - INFO - Epoch 140/2000 - Training Loss: 0.0291 - Validation Loss: 0.0528
# 2025-03-19 23:36:10,372 - INFO - Epoch 141/2000 - Training Loss: 0.0312 - Validation Loss: 0.0527
# 2025-03-19 23:36:10,379 - INFO - Epoch 142/2000 - Training Loss: 0.0289 - Validation Loss: 0.0575
# 2025-03-19 23:36:10,387 - INFO - Epoch 143/2000 - Training Loss: 0.0307 - Validation Loss: 0.0572
# 2025-03-19 23:36:10,394 - INFO - Epoch 144/2000 - Training Loss: 0.0288 - Validation Loss: 0.0539
# 2025-03-19 23:36:10,401 - INFO - Epoch 145/2000 - Training Loss: 0.0307 - Validation Loss: 0.0525
# 2025-03-19 23:36:10,408 - INFO - Epoch 146/2000 - Training Loss: 0.0305 - Validation Loss: 0.0564
# 2025-03-19 23:36:10,427 - INFO - Epoch 147/2000 - Training Loss: 0.0297 - Validation Loss: 0.0547
# 2025-03-19 23:36:10,437 - INFO - Epoch 148/2000 - Training Loss: 0.0300 - Validation Loss: 0.0543
# 2025-03-19 23:36:10,449 - INFO - Epoch 149/2000 - Training Loss: 0.0294 - Validation Loss: 0.0567
# 2025-03-19 23:36:10,457 - INFO - Epoch 150/2000 - Training Loss: 0.0305 - Validation Loss: 0.0537
# 2025-03-19 23:36:10,465 - INFO - Epoch 151/2000 - Training Loss: 0.0276 - Validation Loss: 0.0547
# 2025-03-19 23:36:10,472 - INFO - Epoch 152/2000 - Training Loss: 0.0275 - Validation Loss: 0.0530
# 2025-03-19 23:36:10,479 - INFO - Epoch 153/2000 - Training Loss: 0.0277 - Validation Loss: 0.0534
# 2025-03-19 23:36:10,486 - INFO - Epoch 154/2000 - Training Loss: 0.0277 - Validation Loss: 0.0544
# 2025-03-19 23:36:10,494 - INFO - Epoch 155/2000 - Training Loss: 0.0279 - Validation Loss: 0.0534
# 2025-03-19 23:36:10,501 - INFO - Epoch 156/2000 - Training Loss: 0.0284 - Validation Loss: 0.0563
# 2025-03-19 23:36:10,509 - INFO - Epoch 157/2000 - Training Loss: 0.0282 - Validation Loss: 0.0526
# 2025-03-19 23:36:10,516 - INFO - Epoch 158/2000 - Training Loss: 0.0277 - Validation Loss: 0.0547
# 2025-03-19 23:36:10,524 - INFO - Epoch 159/2000 - Training Loss: 0.0273 - Validation Loss: 0.0537
# 2025-03-19 23:36:10,532 - INFO - Epoch 160/2000 - Training Loss: 0.0278 - Validation Loss: 0.0544
# 2025-03-19 23:36:10,539 - INFO - Epoch 161/2000 - Training Loss: 0.0276 - Validation Loss: 0.0542
# 2025-03-19 23:36:10,546 - INFO - Epoch 162/2000 - Training Loss: 0.0271 - Validation Loss: 0.0531
# 2025-03-19 23:36:10,553 - INFO - Epoch 163/2000 - Training Loss: 0.0279 - Validation Loss: 0.0522
# 2025-03-19 23:36:10,569 - INFO - Epoch 164/2000 - Training Loss: 0.0272 - Validation Loss: 0.0528
# 2025-03-19 23:36:10,576 - INFO - Epoch 165/2000 - Training Loss: 0.0272 - Validation Loss: 0.0519
# 2025-03-19 23:36:10,585 - INFO - Epoch 166/2000 - Training Loss: 0.0273 - Validation Loss: 0.0525
# 2025-03-19 23:36:10,593 - INFO - Epoch 167/2000 - Training Loss: 0.0269 - Validation Loss: 0.0531
# 2025-03-19 23:36:10,600 - INFO - Epoch 168/2000 - Training Loss: 0.0276 - Validation Loss: 0.0536
# 2025-03-19 23:36:10,608 - INFO - Epoch 169/2000 - Training Loss: 0.0278 - Validation Loss: 0.0539
# 2025-03-19 23:36:10,615 - INFO - Epoch 170/2000 - Training Loss: 0.0278 - Validation Loss: 0.0535
# 2025-03-19 23:36:10,623 - INFO - Epoch 171/2000 - Training Loss: 0.0275 - Validation Loss: 0.0529
# 2025-03-19 23:36:10,630 - INFO - Epoch 172/2000 - Training Loss: 0.0268 - Validation Loss: 0.0526
# 2025-03-19 23:36:10,637 - INFO - Epoch 173/2000 - Training Loss: 0.0269 - Validation Loss: 0.0511
# 2025-03-19 23:36:10,645 - INFO - Epoch 174/2000 - Training Loss: 0.0269 - Validation Loss: 0.0521
# 2025-03-19 23:36:10,652 - INFO - Epoch 175/2000 - Training Loss: 0.0278 - Validation Loss: 0.0509
# 2025-03-19 23:36:10,666 - INFO - Epoch 176/2000 - Training Loss: 0.0276 - Validation Loss: 0.0526
# 2025-03-19 23:36:10,673 - INFO - Epoch 177/2000 - Training Loss: 0.0270 - Validation Loss: 0.0530
# 2025-03-19 23:36:10,681 - INFO - Epoch 178/2000 - Training Loss: 0.0270 - Validation Loss: 0.0507
# 2025-03-19 23:36:10,688 - INFO - Epoch 179/2000 - Training Loss: 0.0273 - Validation Loss: 0.0511
# 2025-03-19 23:36:10,695 - INFO - Epoch 180/2000 - Training Loss: 0.0266 - Validation Loss: 0.0532
# 2025-03-19 23:36:10,703 - INFO - Epoch 181/2000 - Training Loss: 0.0274 - Validation Loss: 0.0519
# 2025-03-19 23:36:10,710 - INFO - Epoch 182/2000 - Training Loss: 0.0269 - Validation Loss: 0.0524
# 2025-03-19 23:36:10,717 - INFO - Epoch 183/2000 - Training Loss: 0.0269 - Validation Loss: 0.0514
# 2025-03-19 23:36:10,724 - INFO - Epoch 184/2000 - Training Loss: 0.0270 - Validation Loss: 0.0524
# 2025-03-19 23:36:10,732 - INFO - Epoch 185/2000 - Training Loss: 0.0271 - Validation Loss: 0.0507
# 2025-03-19 23:36:10,739 - INFO - Epoch 186/2000 - Training Loss: 0.0276 - Validation Loss: 0.0547
# 2025-03-19 23:36:10,746 - INFO - Epoch 187/2000 - Training Loss: 0.0268 - Validation Loss: 0.0503
# 2025-03-19 23:36:10,753 - INFO - Epoch 188/2000 - Training Loss: 0.0263 - Validation Loss: 0.0532
# 2025-03-19 23:36:10,761 - INFO - Epoch 189/2000 - Training Loss: 0.0264 - Validation Loss: 0.0516
# 2025-03-19 23:36:10,768 - INFO - Epoch 190/2000 - Training Loss: 0.0266 - Validation Loss: 0.0527
# 2025-03-19 23:36:10,775 - INFO - Epoch 191/2000 - Training Loss: 0.0266 - Validation Loss: 0.0503
# 2025-03-19 23:36:10,789 - INFO - Epoch 192/2000 - Training Loss: 0.0263 - Validation Loss: 0.0524
# 2025-03-19 23:36:10,796 - INFO - Epoch 193/2000 - Training Loss: 0.0262 - Validation Loss: 0.0501
# 2025-03-19 23:36:10,806 - INFO - Epoch 194/2000 - Training Loss: 0.0266 - Validation Loss: 0.0522
# 2025-03-19 23:36:10,813 - INFO - Epoch 195/2000 - Training Loss: 0.0266 - Validation Loss: 0.0513
# 2025-03-19 23:36:10,820 - INFO - Epoch 196/2000 - Training Loss: 0.0259 - Validation Loss: 0.0516
# 2025-03-19 23:36:10,827 - INFO - Epoch 197/2000 - Training Loss: 0.0266 - Validation Loss: 0.0532
# 2025-03-19 23:36:10,834 - INFO - Epoch 198/2000 - Training Loss: 0.0260 - Validation Loss: 0.0510
# 2025-03-19 23:36:10,841 - INFO - Epoch 199/2000 - Training Loss: 0.0259 - Validation Loss: 0.0516
# 2025-03-19 23:36:10,848 - INFO - Epoch 200/2000 - Training Loss: 0.0261 - Validation Loss: 0.0501
# 2025-03-19 23:36:10,855 - INFO - Epoch 201/2000 - Training Loss: 0.0266 - Validation Loss: 0.0537
# 2025-03-19 23:36:10,862 - INFO - Epoch 202/2000 - Training Loss: 0.0263 - Validation Loss: 0.0502
# 2025-03-19 23:36:10,869 - INFO - Epoch 203/2000 - Training Loss: 0.0262 - Validation Loss: 0.0521
# 2025-03-19 23:36:10,876 - INFO - Epoch 204/2000 - Training Loss: 0.0259 - Validation Loss: 0.0504
# 2025-03-19 23:36:10,883 - INFO - Epoch 205/2000 - Training Loss: 0.0260 - Validation Loss: 0.0520
# 2025-03-19 23:36:10,890 - INFO - Epoch 206/2000 - Training Loss: 0.0259 - Validation Loss: 0.0494
# 2025-03-19 23:36:10,897 - INFO - Epoch 207/2000 - Training Loss: 0.0264 - Validation Loss: 0.0504
# 2025-03-19 23:36:10,904 - INFO - Epoch 208/2000 - Training Loss: 0.0257 - Validation Loss: 0.0503
# 2025-03-19 23:36:10,911 - INFO - Epoch 209/2000 - Training Loss: 0.0263 - Validation Loss: 0.0501
# 2025-03-19 23:36:10,919 - INFO - Epoch 210/2000 - Training Loss: 0.0257 - Validation Loss: 0.0500
# 2025-03-19 23:36:10,926 - INFO - Epoch 211/2000 - Training Loss: 0.0261 - Validation Loss: 0.0532
# 2025-03-19 23:36:10,933 - INFO - Epoch 212/2000 - Training Loss: 0.0253 - Validation Loss: 0.0495
# 2025-03-19 23:36:10,940 - INFO - Epoch 213/2000 - Training Loss: 0.0254 - Validation Loss: 0.0494
# 2025-03-19 23:36:10,947 - INFO - Epoch 214/2000 - Training Loss: 0.0252 - Validation Loss: 0.0500
# 2025-03-19 23:36:10,954 - INFO - Epoch 215/2000 - Training Loss: 0.0254 - Validation Loss: 0.0496
# 2025-03-19 23:36:10,961 - INFO - Epoch 216/2000 - Training Loss: 0.0256 - Validation Loss: 0.0500
# 2025-03-19 23:36:10,968 - INFO - Epoch 217/2000 - Training Loss: 0.0251 - Validation Loss: 0.0499
# 2025-03-19 23:36:10,975 - INFO - Epoch 218/2000 - Training Loss: 0.0256 - Validation Loss: 0.0495
# 2025-03-19 23:36:10,982 - INFO - Epoch 219/2000 - Training Loss: 0.0260 - Validation Loss: 0.0487
# 2025-03-19 23:36:10,989 - INFO - Epoch 220/2000 - Training Loss: 0.0263 - Validation Loss: 0.0520
# 2025-03-19 23:36:10,996 - INFO - Epoch 221/2000 - Training Loss: 0.0254 - Validation Loss: 0.0506
# 2025-03-19 23:36:11,003 - INFO - Epoch 222/2000 - Training Loss: 0.0253 - Validation Loss: 0.0492
# 2025-03-19 23:36:11,011 - INFO - Epoch 223/2000 - Training Loss: 0.0251 - Validation Loss: 0.0494
# 2025-03-19 23:36:11,019 - INFO - Epoch 224/2000 - Training Loss: 0.0254 - Validation Loss: 0.0501
# 2025-03-19 23:36:11,026 - INFO - Epoch 225/2000 - Training Loss: 0.0248 - Validation Loss: 0.0511
# 2025-03-19 23:36:11,033 - INFO - Epoch 226/2000 - Training Loss: 0.0259 - Validation Loss: 0.0513
# 2025-03-19 23:36:11,040 - INFO - Epoch 227/2000 - Training Loss: 0.0255 - Validation Loss: 0.0506
# 2025-03-19 23:36:11,047 - INFO - Epoch 228/2000 - Training Loss: 0.0257 - Validation Loss: 0.0490
# 2025-03-19 23:36:11,055 - INFO - Epoch 229/2000 - Training Loss: 0.0248 - Validation Loss: 0.0514
# 2025-03-19 23:36:11,062 - INFO - Epoch 230/2000 - Training Loss: 0.0254 - Validation Loss: 0.0480
# 2025-03-19 23:36:11,069 - INFO - Epoch 231/2000 - Training Loss: 0.0254 - Validation Loss: 0.0525
# 2025-03-19 23:36:11,076 - INFO - Epoch 232/2000 - Training Loss: 0.0250 - Validation Loss: 0.0488
# 2025-03-19 23:36:11,084 - INFO - Epoch 233/2000 - Training Loss: 0.0249 - Validation Loss: 0.0506
# 2025-03-19 23:36:11,091 - INFO - Epoch 234/2000 - Training Loss: 0.0245 - Validation Loss: 0.0482
# 2025-03-19 23:36:11,098 - INFO - Epoch 235/2000 - Training Loss: 0.0247 - Validation Loss: 0.0482
# 2025-03-19 23:36:11,105 - INFO - Epoch 236/2000 - Training Loss: 0.0249 - Validation Loss: 0.0494
# 2025-03-19 23:36:11,112 - INFO - Epoch 237/2000 - Training Loss: 0.0247 - Validation Loss: 0.0489
# 2025-03-19 23:36:11,120 - INFO - Epoch 238/2000 - Training Loss: 0.0250 - Validation Loss: 0.0492
# 2025-03-19 23:36:11,127 - INFO - Epoch 239/2000 - Training Loss: 0.0261 - Validation Loss: 0.0489
# 2025-03-19 23:36:11,134 - INFO - Epoch 240/2000 - Training Loss: 0.0247 - Validation Loss: 0.0479
# 2025-03-19 23:36:11,142 - INFO - Epoch 241/2000 - Training Loss: 0.0259 - Validation Loss: 0.0486
# 2025-03-19 23:36:11,149 - INFO - Epoch 242/2000 - Training Loss: 0.0249 - Validation Loss: 0.0485
# 2025-03-19 23:36:11,156 - INFO - Epoch 243/2000 - Training Loss: 0.0244 - Validation Loss: 0.0495
# 2025-03-19 23:36:11,164 - INFO - Epoch 244/2000 - Training Loss: 0.0248 - Validation Loss: 0.0494
# 2025-03-19 23:36:11,171 - INFO - Epoch 245/2000 - Training Loss: 0.0243 - Validation Loss: 0.0484
# 2025-03-19 23:36:11,178 - INFO - Epoch 246/2000 - Training Loss: 0.0247 - Validation Loss: 0.0492
# 2025-03-19 23:36:11,185 - INFO - Epoch 247/2000 - Training Loss: 0.0251 - Validation Loss: 0.0491
# 2025-03-19 23:36:11,192 - INFO - Epoch 248/2000 - Training Loss: 0.0255 - Validation Loss: 0.0496
# 2025-03-19 23:36:11,199 - INFO - Epoch 249/2000 - Training Loss: 0.0261 - Validation Loss: 0.0492
# 2025-03-19 23:36:11,206 - INFO - Epoch 250/2000 - Training Loss: 0.0249 - Validation Loss: 0.0481
# 2025-03-19 23:36:11,214 - INFO - Epoch 251/2000 - Training Loss: 0.0248 - Validation Loss: 0.0490
# 2025-03-19 23:36:11,221 - INFO - Epoch 252/2000 - Training Loss: 0.0243 - Validation Loss: 0.0491
# 2025-03-19 23:36:11,228 - INFO - Epoch 253/2000 - Training Loss: 0.0244 - Validation Loss: 0.0478
# 2025-03-19 23:36:11,235 - INFO - Epoch 254/2000 - Training Loss: 0.0258 - Validation Loss: 0.0485
# 2025-03-19 23:36:11,242 - INFO - Epoch 255/2000 - Training Loss: 0.0243 - Validation Loss: 0.0485
# 2025-03-19 23:36:11,250 - INFO - Epoch 256/2000 - Training Loss: 0.0241 - Validation Loss: 0.0482
# 2025-03-19 23:36:11,257 - INFO - Epoch 257/2000 - Training Loss: 0.0241 - Validation Loss: 0.0490
# 2025-03-19 23:36:11,264 - INFO - Epoch 258/2000 - Training Loss: 0.0241 - Validation Loss: 0.0487
# 2025-03-19 23:36:11,271 - INFO - Epoch 259/2000 - Training Loss: 0.0246 - Validation Loss: 0.0492
# 2025-03-19 23:36:11,279 - INFO - Epoch 260/2000 - Training Loss: 0.0242 - Validation Loss: 0.0495
# 2025-03-19 23:36:11,286 - INFO - Epoch 261/2000 - Training Loss: 0.0242 - Validation Loss: 0.0475
# 2025-03-19 23:36:11,293 - INFO - Epoch 262/2000 - Training Loss: 0.0251 - Validation Loss: 0.0483
# 2025-03-19 23:36:11,300 - INFO - Epoch 263/2000 - Training Loss: 0.0248 - Validation Loss: 0.0485
# 2025-03-19 23:36:11,307 - INFO - Epoch 264/2000 - Training Loss: 0.0244 - Validation Loss: 0.0485
# 2025-03-19 23:36:11,315 - INFO - Epoch 265/2000 - Training Loss: 0.0244 - Validation Loss: 0.0476
# 2025-03-19 23:36:11,322 - INFO - Epoch 266/2000 - Training Loss: 0.0237 - Validation Loss: 0.0486
# 2025-03-19 23:36:11,329 - INFO - Epoch 267/2000 - Training Loss: 0.0242 - Validation Loss: 0.0474
# 2025-03-19 23:36:11,337 - INFO - Epoch 268/2000 - Training Loss: 0.0241 - Validation Loss: 0.0479
# 2025-03-19 23:36:11,344 - INFO - Epoch 269/2000 - Training Loss: 0.0242 - Validation Loss: 0.0467
# 2025-03-19 23:36:11,351 - INFO - Epoch 270/2000 - Training Loss: 0.0248 - Validation Loss: 0.0473
# 2025-03-19 23:36:11,358 - INFO - Epoch 271/2000 - Training Loss: 0.0241 - Validation Loss: 0.0474
# 2025-03-19 23:36:11,365 - INFO - Epoch 272/2000 - Training Loss: 0.0243 - Validation Loss: 0.0496
# 2025-03-19 23:36:11,373 - INFO - Epoch 273/2000 - Training Loss: 0.0237 - Validation Loss: 0.0475
# 2025-03-19 23:36:11,380 - INFO - Epoch 274/2000 - Training Loss: 0.0246 - Validation Loss: 0.0494
# 2025-03-19 23:36:11,387 - INFO - Epoch 275/2000 - Training Loss: 0.0240 - Validation Loss: 0.0472
# 2025-03-19 23:36:11,394 - INFO - Epoch 276/2000 - Training Loss: 0.0242 - Validation Loss: 0.0484
# 2025-03-19 23:36:11,401 - INFO - Epoch 277/2000 - Training Loss: 0.0242 - Validation Loss: 0.0486
# 2025-03-19 23:36:11,408 - INFO - Epoch 278/2000 - Training Loss: 0.0243 - Validation Loss: 0.0489
# 2025-03-19 23:36:11,415 - INFO - Epoch 279/2000 - Training Loss: 0.0246 - Validation Loss: 0.0509
# 2025-03-19 23:36:11,422 - INFO - Epoch 280/2000 - Training Loss: 0.0243 - Validation Loss: 0.0466
# 2025-03-19 23:36:11,430 - INFO - Epoch 281/2000 - Training Loss: 0.0236 - Validation Loss: 0.0483
# 2025-03-19 23:36:11,437 - INFO - Epoch 282/2000 - Training Loss: 0.0240 - Validation Loss: 0.0458
# 2025-03-19 23:36:11,444 - INFO - Epoch 283/2000 - Training Loss: 0.0237 - Validation Loss: 0.0473
# 2025-03-19 23:36:11,451 - INFO - Epoch 284/2000 - Training Loss: 0.0235 - Validation Loss: 0.0482
# 2025-03-19 23:36:11,459 - INFO - Epoch 285/2000 - Training Loss: 0.0240 - Validation Loss: 0.0483
# 2025-03-19 23:36:11,466 - INFO - Epoch 286/2000 - Training Loss: 0.0236 - Validation Loss: 0.0479
# 2025-03-19 23:36:11,473 - INFO - Epoch 287/2000 - Training Loss: 0.0238 - Validation Loss: 0.0486
# 2025-03-19 23:36:11,480 - INFO - Epoch 288/2000 - Training Loss: 0.0232 - Validation Loss: 0.0480
# 2025-03-19 23:36:11,487 - INFO - Epoch 289/2000 - Training Loss: 0.0239 - Validation Loss: 0.0488
# 2025-03-19 23:36:11,494 - INFO - Epoch 290/2000 - Training Loss: 0.0255 - Validation Loss: 0.0484
# 2025-03-19 23:36:11,501 - INFO - Epoch 291/2000 - Training Loss: 0.0248 - Validation Loss: 0.0476
# 2025-03-19 23:36:11,519 - INFO - Epoch 292/2000 - Training Loss: 0.0237 - Validation Loss: 0.0477
# 2025-03-19 23:36:11,526 - INFO - Epoch 293/2000 - Training Loss: 0.0232 - Validation Loss: 0.0471
# 2025-03-19 23:36:11,533 - INFO - Epoch 294/2000 - Training Loss: 0.0232 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,541 - INFO - Epoch 295/2000 - Training Loss: 0.0242 - Validation Loss: 0.0479
# 2025-03-19 23:36:11,548 - INFO - Epoch 296/2000 - Training Loss: 0.0232 - Validation Loss: 0.0481
# 2025-03-19 23:36:11,555 - INFO - Epoch 297/2000 - Training Loss: 0.0235 - Validation Loss: 0.0471
# 2025-03-19 23:36:11,562 - INFO - Epoch 298/2000 - Training Loss: 0.0234 - Validation Loss: 0.0475
# 2025-03-19 23:36:11,570 - INFO - Epoch 299/2000 - Training Loss: 0.0235 - Validation Loss: 0.0456
# 2025-03-19 23:36:11,577 - INFO - Epoch 300/2000 - Training Loss: 0.0232 - Validation Loss: 0.0464
# 2025-03-19 23:36:11,584 - INFO - Epoch 301/2000 - Training Loss: 0.0231 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,591 - INFO - Epoch 302/2000 - Training Loss: 0.0225 - Validation Loss: 0.0465
# 2025-03-19 23:36:11,598 - INFO - Epoch 303/2000 - Training Loss: 0.0228 - Validation Loss: 0.0473
# 2025-03-19 23:36:11,606 - INFO - Epoch 304/2000 - Training Loss: 0.0227 - Validation Loss: 0.0464
# 2025-03-19 23:36:11,613 - INFO - Epoch 305/2000 - Training Loss: 0.0227 - Validation Loss: 0.0466
# 2025-03-19 23:36:11,620 - INFO - Epoch 306/2000 - Training Loss: 0.0228 - Validation Loss: 0.0466
# 2025-03-19 23:36:11,627 - INFO - Epoch 307/2000 - Training Loss: 0.0226 - Validation Loss: 0.0464
# 2025-03-19 23:36:11,634 - INFO - Epoch 308/2000 - Training Loss: 0.0227 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,641 - INFO - Epoch 309/2000 - Training Loss: 0.0227 - Validation Loss: 0.0457
# 2025-03-19 23:36:11,648 - INFO - Epoch 310/2000 - Training Loss: 0.0226 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,656 - INFO - Epoch 311/2000 - Training Loss: 0.0226 - Validation Loss: 0.0465
# 2025-03-19 23:36:11,663 - INFO - Epoch 312/2000 - Training Loss: 0.0226 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,670 - INFO - Epoch 313/2000 - Training Loss: 0.0226 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,677 - INFO - Epoch 314/2000 - Training Loss: 0.0228 - Validation Loss: 0.0468
# 2025-03-19 23:36:11,684 - INFO - Epoch 315/2000 - Training Loss: 0.0227 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,691 - INFO - Epoch 316/2000 - Training Loss: 0.0225 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,698 - INFO - Epoch 317/2000 - Training Loss: 0.0227 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,705 - INFO - Epoch 318/2000 - Training Loss: 0.0227 - Validation Loss: 0.0464
# 2025-03-19 23:36:11,713 - INFO - Epoch 319/2000 - Training Loss: 0.0223 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,720 - INFO - Epoch 320/2000 - Training Loss: 0.0227 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,727 - INFO - Epoch 321/2000 - Training Loss: 0.0225 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,734 - INFO - Epoch 322/2000 - Training Loss: 0.0225 - Validation Loss: 0.0473
# 2025-03-19 23:36:11,741 - INFO - Epoch 323/2000 - Training Loss: 0.0222 - Validation Loss: 0.0458
# 2025-03-19 23:36:11,748 - INFO - Epoch 324/2000 - Training Loss: 0.0227 - Validation Loss: 0.0463
# 2025-03-19 23:36:11,755 - INFO - Epoch 325/2000 - Training Loss: 0.0225 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,762 - INFO - Epoch 326/2000 - Training Loss: 0.0226 - Validation Loss: 0.0475
# 2025-03-19 23:36:11,769 - INFO - Epoch 327/2000 - Training Loss: 0.0224 - Validation Loss: 0.0454
# 2025-03-19 23:36:11,777 - INFO - Epoch 328/2000 - Training Loss: 0.0225 - Validation Loss: 0.0467
# 2025-03-19 23:36:11,784 - INFO - Epoch 329/2000 - Training Loss: 0.0225 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,791 - INFO - Epoch 330/2000 - Training Loss: 0.0226 - Validation Loss: 0.0467
# 2025-03-19 23:36:11,798 - INFO - Epoch 331/2000 - Training Loss: 0.0224 - Validation Loss: 0.0455
# 2025-03-19 23:36:11,805 - INFO - Epoch 332/2000 - Training Loss: 0.0229 - Validation Loss: 0.0466
# 2025-03-19 23:36:11,812 - INFO - Epoch 333/2000 - Training Loss: 0.0225 - Validation Loss: 0.0471
# 2025-03-19 23:36:11,819 - INFO - Epoch 334/2000 - Training Loss: 0.0224 - Validation Loss: 0.0464
# 2025-03-19 23:36:11,826 - INFO - Epoch 335/2000 - Training Loss: 0.0224 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,834 - INFO - Epoch 336/2000 - Training Loss: 0.0222 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,841 - INFO - Epoch 337/2000 - Training Loss: 0.0223 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,848 - INFO - Epoch 338/2000 - Training Loss: 0.0221 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,855 - INFO - Epoch 339/2000 - Training Loss: 0.0224 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,863 - INFO - Epoch 340/2000 - Training Loss: 0.0226 - Validation Loss: 0.0465
# 2025-03-19 23:36:11,870 - INFO - Epoch 341/2000 - Training Loss: 0.0223 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,877 - INFO - Epoch 342/2000 - Training Loss: 0.0225 - Validation Loss: 0.0460
# 2025-03-19 23:36:11,884 - INFO - Epoch 343/2000 - Training Loss: 0.0225 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,901 - INFO - Epoch 344/2000 - Training Loss: 0.0225 - Validation Loss: 0.0457
# 2025-03-19 23:36:11,909 - INFO - Epoch 345/2000 - Training Loss: 0.0225 - Validation Loss: 0.0469
# 2025-03-19 23:36:11,916 - INFO - Epoch 346/2000 - Training Loss: 0.0232 - Validation Loss: 0.0461
# 2025-03-19 23:36:11,923 - INFO - Epoch 347/2000 - Training Loss: 0.0226 - Validation Loss: 0.0468
# 2025-03-19 23:36:11,931 - INFO - Epoch 348/2000 - Training Loss: 0.0220 - Validation Loss: 0.0467
# 2025-03-19 23:36:11,938 - INFO - Epoch 349/2000 - Training Loss: 0.0225 - Validation Loss: 0.0458
# 2025-03-19 23:36:11,945 - INFO - Epoch 350/2000 - Training Loss: 0.0226 - Validation Loss: 0.0459
# 2025-03-19 23:36:11,952 - INFO - Epoch 351/2000 - Training Loss: 0.0226 - Validation Loss: 0.0462
# 2025-03-19 23:36:11,959 - INFO - Epoch 352/2000 - Training Loss: 0.0219 - Validation Loss: 0.0458
# 2025-03-19 23:36:11,966 - INFO - Epoch 353/2000 - Training Loss: 0.0219 - Validation Loss: 0.0466
# 2025-03-19 23:36:11,973 - INFO - Epoch 354/2000 - Training Loss: 0.0227 - Validation Loss: 0.0458
# 2025-03-19 23:36:11,980 - INFO - Epoch 355/2000 - Training Loss: 0.0224 - Validation Loss: 0.0474
# 2025-03-19 23:36:11,988 - INFO - Epoch 356/2000 - Training Loss: 0.0225 - Validation Loss: 0.0457
# 2025-03-19 23:36:11,995 - INFO - Epoch 357/2000 - Training Loss: 0.0219 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,002 - INFO - Epoch 358/2000 - Training Loss: 0.0220 - Validation Loss: 0.0463
# 2025-03-19 23:36:12,009 - INFO - Epoch 359/2000 - Training Loss: 0.0220 - Validation Loss: 0.0462
# 2025-03-19 23:36:12,016 - INFO - Epoch 360/2000 - Training Loss: 0.0219 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,024 - INFO - Epoch 361/2000 - Training Loss: 0.0227 - Validation Loss: 0.0451
# 2025-03-19 23:36:12,031 - INFO - Epoch 362/2000 - Training Loss: 0.0224 - Validation Loss: 0.0462
# 2025-03-19 23:36:12,038 - INFO - Epoch 363/2000 - Training Loss: 0.0219 - Validation Loss: 0.0465
# 2025-03-19 23:36:12,045 - INFO - Epoch 364/2000 - Training Loss: 0.0221 - Validation Loss: 0.0457
# 2025-03-19 23:36:12,052 - INFO - Epoch 365/2000 - Training Loss: 0.0217 - Validation Loss: 0.0458
# 2025-03-19 23:36:12,059 - INFO - Epoch 366/2000 - Training Loss: 0.0220 - Validation Loss: 0.0464
# 2025-03-19 23:36:12,066 - INFO - Epoch 367/2000 - Training Loss: 0.0221 - Validation Loss: 0.0465
# 2025-03-19 23:36:12,074 - INFO - Epoch 368/2000 - Training Loss: 0.0223 - Validation Loss: 0.0466
# 2025-03-19 23:36:12,081 - INFO - Epoch 369/2000 - Training Loss: 0.0220 - Validation Loss: 0.0456
# 2025-03-19 23:36:12,088 - INFO - Epoch 370/2000 - Training Loss: 0.0219 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,096 - INFO - Epoch 371/2000 - Training Loss: 0.0220 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,103 - INFO - Epoch 372/2000 - Training Loss: 0.0219 - Validation Loss: 0.0462
# 2025-03-19 23:36:12,110 - INFO - Epoch 373/2000 - Training Loss: 0.0220 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,117 - INFO - Epoch 374/2000 - Training Loss: 0.0222 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,125 - INFO - Epoch 375/2000 - Training Loss: 0.0218 - Validation Loss: 0.0463
# 2025-03-19 23:36:12,132 - INFO - Epoch 376/2000 - Training Loss: 0.0219 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,139 - INFO - Epoch 377/2000 - Training Loss: 0.0223 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,146 - INFO - Epoch 378/2000 - Training Loss: 0.0220 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,154 - INFO - Epoch 379/2000 - Training Loss: 0.0224 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,161 - INFO - Epoch 380/2000 - Training Loss: 0.0226 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,168 - INFO - Epoch 381/2000 - Training Loss: 0.0219 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,175 - INFO - Epoch 382/2000 - Training Loss: 0.0218 - Validation Loss: 0.0470
# 2025-03-19 23:36:12,183 - INFO - Epoch 383/2000 - Training Loss: 0.0220 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,190 - INFO - Epoch 384/2000 - Training Loss: 0.0220 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,197 - INFO - Epoch 385/2000 - Training Loss: 0.0219 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,204 - INFO - Epoch 386/2000 - Training Loss: 0.0217 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,212 - INFO - Epoch 387/2000 - Training Loss: 0.0217 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,219 - INFO - Epoch 388/2000 - Training Loss: 0.0218 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,226 - INFO - Epoch 389/2000 - Training Loss: 0.0216 - Validation Loss: 0.0462
# 2025-03-19 23:36:12,234 - INFO - Epoch 390/2000 - Training Loss: 0.0218 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,241 - INFO - Epoch 391/2000 - Training Loss: 0.0218 - Validation Loss: 0.0454
# 2025-03-19 23:36:12,248 - INFO - Epoch 392/2000 - Training Loss: 0.0218 - Validation Loss: 0.0464
# 2025-03-19 23:36:12,255 - INFO - Epoch 393/2000 - Training Loss: 0.0215 - Validation Loss: 0.0458
# 2025-03-19 23:36:12,263 - INFO - Epoch 394/2000 - Training Loss: 0.0216 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,270 - INFO - Epoch 395/2000 - Training Loss: 0.0217 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,277 - INFO - Epoch 396/2000 - Training Loss: 0.0221 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,284 - INFO - Epoch 397/2000 - Training Loss: 0.0218 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,292 - INFO - Epoch 398/2000 - Training Loss: 0.0217 - Validation Loss: 0.0454
# 2025-03-19 23:36:12,299 - INFO - Epoch 399/2000 - Training Loss: 0.0219 - Validation Loss: 0.0460
# 2025-03-19 23:36:12,306 - INFO - Epoch 400/2000 - Training Loss: 0.0218 - Validation Loss: 0.0454
# 2025-03-19 23:36:12,314 - INFO - Epoch 401/2000 - Training Loss: 0.0215 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,321 - INFO - Epoch 402/2000 - Training Loss: 0.0217 - Validation Loss: 0.0458
# 2025-03-19 23:36:12,328 - INFO - Epoch 403/2000 - Training Loss: 0.0221 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,335 - INFO - Epoch 404/2000 - Training Loss: 0.0219 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,343 - INFO - Epoch 405/2000 - Training Loss: 0.0214 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,350 - INFO - Epoch 406/2000 - Training Loss: 0.0216 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,357 - INFO - Epoch 407/2000 - Training Loss: 0.0216 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,365 - INFO - Epoch 408/2000 - Training Loss: 0.0216 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,372 - INFO - Epoch 409/2000 - Training Loss: 0.0215 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,379 - INFO - Epoch 410/2000 - Training Loss: 0.0216 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,386 - INFO - Epoch 411/2000 - Training Loss: 0.0217 - Validation Loss: 0.0456
# 2025-03-19 23:36:12,394 - INFO - Epoch 412/2000 - Training Loss: 0.0217 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,401 - INFO - Epoch 413/2000 - Training Loss: 0.0215 - Validation Loss: 0.0450
# 2025-03-19 23:36:12,408 - INFO - Epoch 414/2000 - Training Loss: 0.0214 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,415 - INFO - Epoch 415/2000 - Training Loss: 0.0217 - Validation Loss: 0.0456
# 2025-03-19 23:36:12,423 - INFO - Epoch 416/2000 - Training Loss: 0.0218 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,430 - INFO - Epoch 417/2000 - Training Loss: 0.0215 - Validation Loss: 0.0451
# 2025-03-19 23:36:12,437 - INFO - Epoch 418/2000 - Training Loss: 0.0216 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,445 - INFO - Epoch 419/2000 - Training Loss: 0.0216 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,452 - INFO - Epoch 420/2000 - Training Loss: 0.0216 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,459 - INFO - Epoch 421/2000 - Training Loss: 0.0225 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,466 - INFO - Epoch 422/2000 - Training Loss: 0.0217 - Validation Loss: 0.0456
# 2025-03-19 23:36:12,474 - INFO - Epoch 423/2000 - Training Loss: 0.0217 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,481 - INFO - Epoch 424/2000 - Training Loss: 0.0215 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,488 - INFO - Epoch 425/2000 - Training Loss: 0.0216 - Validation Loss: 0.0459
# 2025-03-19 23:36:12,495 - INFO - Epoch 426/2000 - Training Loss: 0.0213 - Validation Loss: 0.0450
# 2025-03-19 23:36:12,503 - INFO - Epoch 427/2000 - Training Loss: 0.0214 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,510 - INFO - Epoch 428/2000 - Training Loss: 0.0214 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,517 - INFO - Epoch 429/2000 - Training Loss: 0.0214 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,524 - INFO - Epoch 430/2000 - Training Loss: 0.0213 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,531 - INFO - Epoch 431/2000 - Training Loss: 0.0212 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,539 - INFO - Epoch 432/2000 - Training Loss: 0.0218 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,546 - INFO - Epoch 433/2000 - Training Loss: 0.0219 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,553 - INFO - Epoch 434/2000 - Training Loss: 0.0214 - Validation Loss: 0.0461
# 2025-03-19 23:36:12,560 - INFO - Epoch 435/2000 - Training Loss: 0.0213 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,567 - INFO - Epoch 436/2000 - Training Loss: 0.0214 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,575 - INFO - Epoch 437/2000 - Training Loss: 0.0214 - Validation Loss: 0.0454
# 2025-03-19 23:36:12,582 - INFO - Epoch 438/2000 - Training Loss: 0.0211 - Validation Loss: 0.0441
# 2025-03-19 23:36:12,589 - INFO - Epoch 439/2000 - Training Loss: 0.0213 - Validation Loss: 0.0454
# 2025-03-19 23:36:12,596 - INFO - Epoch 440/2000 - Training Loss: 0.0210 - Validation Loss: 0.0443
# 2025-03-19 23:36:12,603 - INFO - Epoch 441/2000 - Training Loss: 0.0216 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,611 - INFO - Epoch 442/2000 - Training Loss: 0.0213 - Validation Loss: 0.0453
# 2025-03-19 23:36:12,618 - INFO - Epoch 443/2000 - Training Loss: 0.0213 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,625 - INFO - Epoch 444/2000 - Training Loss: 0.0213 - Validation Loss: 0.0458
# 2025-03-19 23:36:12,632 - INFO - Epoch 445/2000 - Training Loss: 0.0212 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,639 - INFO - Epoch 446/2000 - Training Loss: 0.0212 - Validation Loss: 0.0443
# 2025-03-19 23:36:12,646 - INFO - Epoch 447/2000 - Training Loss: 0.0213 - Validation Loss: 0.0455
# 2025-03-19 23:36:12,654 - INFO - Epoch 448/2000 - Training Loss: 0.0213 - Validation Loss: 0.0451
# 2025-03-19 23:36:12,661 - INFO - Epoch 449/2000 - Training Loss: 0.0211 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,668 - INFO - Epoch 450/2000 - Training Loss: 0.0211 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,675 - INFO - Epoch 451/2000 - Training Loss: 0.0212 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,683 - INFO - Epoch 452/2000 - Training Loss: 0.0211 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,690 - INFO - Epoch 453/2000 - Training Loss: 0.0210 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,697 - INFO - Epoch 454/2000 - Training Loss: 0.0210 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,704 - INFO - Epoch 455/2000 - Training Loss: 0.0210 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,711 - INFO - Epoch 456/2000 - Training Loss: 0.0209 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,719 - INFO - Epoch 457/2000 - Training Loss: 0.0210 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,726 - INFO - Epoch 458/2000 - Training Loss: 0.0210 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,733 - INFO - Epoch 459/2000 - Training Loss: 0.0210 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,740 - INFO - Epoch 460/2000 - Training Loss: 0.0211 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,747 - INFO - Epoch 461/2000 - Training Loss: 0.0207 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,754 - INFO - Epoch 462/2000 - Training Loss: 0.0209 - Validation Loss: 0.0441
# 2025-03-19 23:36:12,762 - INFO - Epoch 463/2000 - Training Loss: 0.0209 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,769 - INFO - Epoch 464/2000 - Training Loss: 0.0208 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,776 - INFO - Epoch 465/2000 - Training Loss: 0.0209 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,784 - INFO - Epoch 466/2000 - Training Loss: 0.0209 - Validation Loss: 0.0449
# 2025-03-19 23:36:12,791 - INFO - Epoch 467/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,798 - INFO - Epoch 468/2000 - Training Loss: 0.0209 - Validation Loss: 0.0442
# 2025-03-19 23:36:12,805 - INFO - Epoch 469/2000 - Training Loss: 0.0211 - Validation Loss: 0.0443
# 2025-03-19 23:36:12,812 - INFO - Epoch 470/2000 - Training Loss: 0.0210 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,819 - INFO - Epoch 471/2000 - Training Loss: 0.0211 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,827 - INFO - Epoch 472/2000 - Training Loss: 0.0212 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,834 - INFO - Epoch 473/2000 - Training Loss: 0.0210 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,841 - INFO - Epoch 474/2000 - Training Loss: 0.0209 - Validation Loss: 0.0439
# 2025-03-19 23:36:12,848 - INFO - Epoch 475/2000 - Training Loss: 0.0211 - Validation Loss: 0.0447
# 2025-03-19 23:36:12,855 - INFO - Epoch 476/2000 - Training Loss: 0.0208 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,863 - INFO - Epoch 477/2000 - Training Loss: 0.0209 - Validation Loss: 0.0441
# 2025-03-19 23:36:12,870 - INFO - Epoch 478/2000 - Training Loss: 0.0210 - Validation Loss: 0.0452
# 2025-03-19 23:36:12,877 - INFO - Epoch 479/2000 - Training Loss: 0.0209 - Validation Loss: 0.0440
# 2025-03-19 23:36:12,884 - INFO - Epoch 480/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,892 - INFO - Epoch 481/2000 - Training Loss: 0.0209 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,899 - INFO - Epoch 482/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,906 - INFO - Epoch 483/2000 - Training Loss: 0.0208 - Validation Loss: 0.0448
# 2025-03-19 23:36:12,914 - INFO - Epoch 484/2000 - Training Loss: 0.0210 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,921 - INFO - Epoch 485/2000 - Training Loss: 0.0208 - Validation Loss: 0.0446
# 2025-03-19 23:36:12,928 - INFO - Epoch 486/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:12,935 - INFO - Epoch 487/2000 - Training Loss: 0.0210 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,942 - INFO - Epoch 488/2000 - Training Loss: 0.0208 - Validation Loss: 0.0442
# 2025-03-19 23:36:12,950 - INFO - Epoch 489/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,957 - INFO - Epoch 490/2000 - Training Loss: 0.0212 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,964 - INFO - Epoch 491/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:12,971 - INFO - Epoch 492/2000 - Training Loss: 0.0209 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,978 - INFO - Epoch 493/2000 - Training Loss: 0.0209 - Validation Loss: 0.0445
# 2025-03-19 23:36:12,985 - INFO - Epoch 494/2000 - Training Loss: 0.0208 - Validation Loss: 0.0444
# 2025-03-19 23:36:12,993 - INFO - Epoch 495/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,000 - INFO - Epoch 496/2000 - Training Loss: 0.0209 - Validation Loss: 0.0447
# 2025-03-19 23:36:13,007 - INFO - Epoch 497/2000 - Training Loss: 0.0207 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,014 - INFO - Epoch 498/2000 - Training Loss: 0.0208 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,021 - INFO - Epoch 499/2000 - Training Loss: 0.0209 - Validation Loss: 0.0446
# 2025-03-19 23:36:13,029 - INFO - Epoch 500/2000 - Training Loss: 0.0208 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,036 - INFO - Epoch 501/2000 - Training Loss: 0.0208 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,043 - INFO - Epoch 502/2000 - Training Loss: 0.0207 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,050 - INFO - Epoch 503/2000 - Training Loss: 0.0208 - Validation Loss: 0.0444
# 2025-03-19 23:36:13,057 - INFO - Epoch 504/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:13,065 - INFO - Epoch 505/2000 - Training Loss: 0.0208 - Validation Loss: 0.0444
# 2025-03-19 23:36:13,072 - INFO - Epoch 506/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,079 - INFO - Epoch 507/2000 - Training Loss: 0.0208 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,086 - INFO - Epoch 508/2000 - Training Loss: 0.0207 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,094 - INFO - Epoch 509/2000 - Training Loss: 0.0208 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,101 - INFO - Epoch 510/2000 - Training Loss: 0.0207 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,108 - INFO - Epoch 511/2000 - Training Loss: 0.0210 - Validation Loss: 0.0449
# 2025-03-19 23:36:13,115 - INFO - Epoch 512/2000 - Training Loss: 0.0206 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,122 - INFO - Epoch 513/2000 - Training Loss: 0.0207 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,130 - INFO - Epoch 514/2000 - Training Loss: 0.0206 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,137 - INFO - Epoch 515/2000 - Training Loss: 0.0210 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,144 - INFO - Epoch 516/2000 - Training Loss: 0.0205 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,151 - INFO - Epoch 517/2000 - Training Loss: 0.0206 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,158 - INFO - Epoch 518/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,166 - INFO - Epoch 519/2000 - Training Loss: 0.0209 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,173 - INFO - Epoch 520/2000 - Training Loss: 0.0206 - Validation Loss: 0.0445
# 2025-03-19 23:36:13,180 - INFO - Epoch 521/2000 - Training Loss: 0.0206 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,187 - INFO - Epoch 522/2000 - Training Loss: 0.0205 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,195 - INFO - Epoch 523/2000 - Training Loss: 0.0206 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,202 - INFO - Epoch 524/2000 - Training Loss: 0.0207 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,209 - INFO - Epoch 525/2000 - Training Loss: 0.0206 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,216 - INFO - Epoch 526/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,223 - INFO - Epoch 527/2000 - Training Loss: 0.0206 - Validation Loss: 0.0445
# 2025-03-19 23:36:13,230 - INFO - Epoch 528/2000 - Training Loss: 0.0205 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,238 - INFO - Epoch 529/2000 - Training Loss: 0.0207 - Validation Loss: 0.0446
# 2025-03-19 23:36:13,245 - INFO - Epoch 530/2000 - Training Loss: 0.0207 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,252 - INFO - Epoch 531/2000 - Training Loss: 0.0207 - Validation Loss: 0.0444
# 2025-03-19 23:36:13,259 - INFO - Epoch 532/2000 - Training Loss: 0.0207 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,267 - INFO - Epoch 533/2000 - Training Loss: 0.0205 - Validation Loss: 0.0446
# 2025-03-19 23:36:13,274 - INFO - Epoch 534/2000 - Training Loss: 0.0206 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,281 - INFO - Epoch 535/2000 - Training Loss: 0.0207 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,288 - INFO - Epoch 536/2000 - Training Loss: 0.0208 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,296 - INFO - Epoch 537/2000 - Training Loss: 0.0206 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,303 - INFO - Epoch 538/2000 - Training Loss: 0.0207 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,310 - INFO - Epoch 539/2000 - Training Loss: 0.0206 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,317 - INFO - Epoch 540/2000 - Training Loss: 0.0206 - Validation Loss: 0.0447
# 2025-03-19 23:36:13,324 - INFO - Epoch 541/2000 - Training Loss: 0.0207 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,332 - INFO - Epoch 542/2000 - Training Loss: 0.0207 - Validation Loss: 0.0451
# 2025-03-19 23:36:13,339 - INFO - Epoch 543/2000 - Training Loss: 0.0209 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,346 - INFO - Epoch 544/2000 - Training Loss: 0.0205 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,353 - INFO - Epoch 545/2000 - Training Loss: 0.0206 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,360 - INFO - Epoch 546/2000 - Training Loss: 0.0206 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,368 - INFO - Epoch 547/2000 - Training Loss: 0.0205 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,375 - INFO - Epoch 548/2000 - Training Loss: 0.0205 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,382 - INFO - Epoch 549/2000 - Training Loss: 0.0204 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,389 - INFO - Epoch 550/2000 - Training Loss: 0.0206 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,396 - INFO - Epoch 551/2000 - Training Loss: 0.0205 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,404 - INFO - Epoch 552/2000 - Training Loss: 0.0208 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,411 - INFO - Epoch 553/2000 - Training Loss: 0.0206 - Validation Loss: 0.0445
# 2025-03-19 23:36:13,418 - INFO - Epoch 554/2000 - Training Loss: 0.0205 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,425 - INFO - Epoch 555/2000 - Training Loss: 0.0208 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,432 - INFO - Epoch 556/2000 - Training Loss: 0.0205 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,440 - INFO - Epoch 557/2000 - Training Loss: 0.0206 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,447 - INFO - Epoch 558/2000 - Training Loss: 0.0207 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,454 - INFO - Epoch 559/2000 - Training Loss: 0.0205 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,461 - INFO - Epoch 560/2000 - Training Loss: 0.0205 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,469 - INFO - Epoch 561/2000 - Training Loss: 0.0206 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,476 - INFO - Epoch 562/2000 - Training Loss: 0.0206 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,483 - INFO - Epoch 563/2000 - Training Loss: 0.0204 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,490 - INFO - Epoch 564/2000 - Training Loss: 0.0205 - Validation Loss: 0.0444
# 2025-03-19 23:36:13,498 - INFO - Epoch 565/2000 - Training Loss: 0.0206 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,505 - INFO - Epoch 566/2000 - Training Loss: 0.0205 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,512 - INFO - Epoch 567/2000 - Training Loss: 0.0207 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,519 - INFO - Epoch 568/2000 - Training Loss: 0.0204 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,526 - INFO - Epoch 569/2000 - Training Loss: 0.0205 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,534 - INFO - Epoch 570/2000 - Training Loss: 0.0206 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,541 - INFO - Epoch 571/2000 - Training Loss: 0.0204 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,548 - INFO - Epoch 572/2000 - Training Loss: 0.0205 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,555 - INFO - Epoch 573/2000 - Training Loss: 0.0203 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,562 - INFO - Epoch 574/2000 - Training Loss: 0.0204 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,570 - INFO - Epoch 575/2000 - Training Loss: 0.0205 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,577 - INFO - Epoch 576/2000 - Training Loss: 0.0205 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,584 - INFO - Epoch 577/2000 - Training Loss: 0.0208 - Validation Loss: 0.0445
# 2025-03-19 23:36:13,591 - INFO - Epoch 578/2000 - Training Loss: 0.0204 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,599 - INFO - Epoch 579/2000 - Training Loss: 0.0205 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,606 - INFO - Epoch 580/2000 - Training Loss: 0.0204 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,613 - INFO - Epoch 581/2000 - Training Loss: 0.0204 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,620 - INFO - Epoch 582/2000 - Training Loss: 0.0205 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,627 - INFO - Epoch 583/2000 - Training Loss: 0.0205 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,635 - INFO - Epoch 584/2000 - Training Loss: 0.0204 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,642 - INFO - Epoch 585/2000 - Training Loss: 0.0203 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,649 - INFO - Epoch 586/2000 - Training Loss: 0.0204 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,656 - INFO - Epoch 587/2000 - Training Loss: 0.0205 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,663 - INFO - Epoch 588/2000 - Training Loss: 0.0204 - Validation Loss: 0.0432
# 2025-03-19 23:36:13,671 - INFO - Epoch 589/2000 - Training Loss: 0.0205 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,678 - INFO - Epoch 590/2000 - Training Loss: 0.0207 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,685 - INFO - Epoch 591/2000 - Training Loss: 0.0205 - Validation Loss: 0.0432
# 2025-03-19 23:36:13,692 - INFO - Epoch 592/2000 - Training Loss: 0.0203 - Validation Loss: 0.0442
# 2025-03-19 23:36:13,699 - INFO - Epoch 593/2000 - Training Loss: 0.0206 - Validation Loss: 0.0443
# 2025-03-19 23:36:13,706 - INFO - Epoch 594/2000 - Training Loss: 0.0204 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,714 - INFO - Epoch 595/2000 - Training Loss: 0.0205 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,721 - INFO - Epoch 596/2000 - Training Loss: 0.0203 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,728 - INFO - Epoch 597/2000 - Training Loss: 0.0204 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,735 - INFO - Epoch 598/2000 - Training Loss: 0.0204 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,742 - INFO - Epoch 599/2000 - Training Loss: 0.0204 - Validation Loss: 0.0441
# 2025-03-19 23:36:13,750 - INFO - Epoch 600/2000 - Training Loss: 0.0203 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,757 - INFO - Epoch 601/2000 - Training Loss: 0.0203 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,765 - INFO - Epoch 602/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,772 - INFO - Epoch 603/2000 - Training Loss: 0.0202 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,779 - INFO - Epoch 604/2000 - Training Loss: 0.0202 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,787 - INFO - Epoch 605/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,794 - INFO - Epoch 606/2000 - Training Loss: 0.0201 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,801 - INFO - Epoch 607/2000 - Training Loss: 0.0203 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,808 - INFO - Epoch 608/2000 - Training Loss: 0.0202 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,816 - INFO - Epoch 609/2000 - Training Loss: 0.0202 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,823 - INFO - Epoch 610/2000 - Training Loss: 0.0203 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,830 - INFO - Epoch 611/2000 - Training Loss: 0.0202 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,838 - INFO - Epoch 612/2000 - Training Loss: 0.0201 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,845 - INFO - Epoch 613/2000 - Training Loss: 0.0202 - Validation Loss: 0.0440
# 2025-03-19 23:36:13,852 - INFO - Epoch 614/2000 - Training Loss: 0.0201 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,859 - INFO - Epoch 615/2000 - Training Loss: 0.0202 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,867 - INFO - Epoch 616/2000 - Training Loss: 0.0202 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,874 - INFO - Epoch 617/2000 - Training Loss: 0.0202 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,881 - INFO - Epoch 618/2000 - Training Loss: 0.0202 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,888 - INFO - Epoch 619/2000 - Training Loss: 0.0202 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,895 - INFO - Epoch 620/2000 - Training Loss: 0.0201 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,903 - INFO - Epoch 621/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,910 - INFO - Epoch 622/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:13,917 - INFO - Epoch 623/2000 - Training Loss: 0.0202 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,927 - INFO - Epoch 624/2000 - Training Loss: 0.0202 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,940 - INFO - Epoch 625/2000 - Training Loss: 0.0202 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,948 - INFO - Epoch 626/2000 - Training Loss: 0.0201 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,955 - INFO - Epoch 627/2000 - Training Loss: 0.0201 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,962 - INFO - Epoch 628/2000 - Training Loss: 0.0202 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,969 - INFO - Epoch 629/2000 - Training Loss: 0.0202 - Validation Loss: 0.0435
# 2025-03-19 23:36:13,976 - INFO - Epoch 630/2000 - Training Loss: 0.0201 - Validation Loss: 0.0438
# 2025-03-19 23:36:13,983 - INFO - Epoch 631/2000 - Training Loss: 0.0201 - Validation Loss: 0.0439
# 2025-03-19 23:36:13,991 - INFO - Epoch 632/2000 - Training Loss: 0.0202 - Validation Loss: 0.0436
# 2025-03-19 23:36:13,998 - INFO - Epoch 633/2000 - Training Loss: 0.0202 - Validation Loss: 0.0435
# 2025-03-19 23:36:14,005 - INFO - Epoch 634/2000 - Training Loss: 0.0201 - Validation Loss: 0.0435
# 2025-03-19 23:36:14,013 - INFO - Epoch 635/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:14,020 - INFO - Epoch 636/2000 - Training Loss: 0.0201 - Validation Loss: 0.0438
# 2025-03-19 23:36:14,027 - INFO - Epoch 637/2000 - Training Loss: 0.0202 - Validation Loss: 0.0437
# 2025-03-19 23:36:14,034 - INFO - Epoch 638/2000 - Training Loss: 0.0201 - Validation Loss: 0.0434
# 2025-03-19 23:36:14,041 - INFO - Epoch 639/2000 - Training Loss: 0.0201 - Validation Loss: 0.0436
# 2025-03-19 23:36:14,049 - INFO - Epoch 640/2000 - Training Loss: 0.0201 - Validation Loss: 0.0436
# 2025-03-19 23:36:14,056 - INFO - Epoch 641/2000 - Training Loss: 0.0201 - Validation Loss: 0.0436
# 2025-03-19 23:36:14,056 - INFO - Early stopping triggered.
# 2025-03-19 23:36:14,056 - INFO - Applying correction to the full target...
# Early stopping triggered after 50 epochs with no improvement.
# Mean ΔE2000 Error: 5.871963412325971
# Max ΔE2000 Error: 17.967206034793644
# 2025-03-19 23:36:14,160 - WARNING - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.05228573..0.9931258].
